# %%
from google.cloud import datastore
import jsonlines, json
client = datastore.Client()
collection = 'suppliers'

f = jsonlines.open('Documents/ict_supplier_analysis/ict_panel_suppliers.jsonl', 'r')

for r in f.iter():
    
    key = client.key(collection, r['ABN'])
    supplier = datastore.Entity(key=key)
    supplier['Name'] = r['Supplier Name']
    supplier['ABN'] = r['ABN']
    supplier['State'] = r['State']
    supplier['Postcode'] = r['Postcode']
    client.put(supplier)
    print('Saved {}: {}'.format(supplier.key.name, supplier['Name']))
    
f.close()
# Out:
# Saved 51137899346: 4DATA Hall 1 Pty Ltd (trading as 4DATA)
# Saved 95127484904: A&A Testing Consultants Pty Ltd
# Saved 13069942552: Access Testing Pty Ltd trading as AccessHQ
# Saved 52150446521: AccessibilityOz Pty Ltd
# Saved 18120507137: Accessity Pty Ltd
# Saved 49800667911: ACSPRO Pty Ltd
# Saved 50169520478: Adaps IT Pty Ltd
# Saved 43096505805: Adelphi Digital Consulting Group Pty Ltd
# Saved 34129384032: AGIS Group Pty Ltd
# Saved 14007145637: Ajilon
# Saved 45119601759: Analytics Group Pty Ltd
# Saved 91125472899: Apis Group Pty Ltd
# Saved 57122300636: Aquasora Pty Ltd
# Saved 15126132590: Aristech Pty Ltd
# Saved 21116237284: Artis Group Pty Ltd
# Saved 57070045117: ASG Group Ltd
# Saved 83123668940: ASPL Australia Pty Ltd
# Saved 60103121464: Aurec Pty ltd
# Saved 90008591008: Aviko Pty Ltd
# Saved 14111187270: BAE Systems Applied Intelligence Pty Limited
# Saved 50175029245: Balance Recruitment Pty Ltd
# Saved 76600455963: Beyond Technology International Pty Ltd t/a Beyond Technology
# Saved 30122228004: BI Group Australia Pty Ltd
# Saved 26300662281: Biztech Enterprise Solutions
# Saved 48106436837: Bluefin Resources Pty Ltd
# Saved 11087255472: Bridge IT Engineering Pty Ltd
# Saved 85156575647: Bright Consulting
# Saved 45096568259: BSI People Pty Ltd
# Saved 23090593525: Bullseye (Asia Pascific) Pty Ltd
# Saved 61121411274: Business Aspect (ACT) Pty Ltd
# Saved 89081322518: Bytecode Pty Ltd
# Saved 40154007664: Callida Consulting
# Saved 57139224436: Canberra Consulting Pty Ltd
# Saved 11092284314: Capgemini Australia Pty Ltd
# Saved 39001260699: CGI Technologies and Solutions Australia Pty Ltd
# Saved 27145006006: Chamonix IT Management Consulting Pty Ltd
# Saved 33090555052: Chandler Macleod Group
# Saved 45108262942: Citadel Systems Pty Ltd
# Saved 83140112205: Clarity Business and IT Solutions Pty Ltd
# Saved 43002724334: Clarius Group Ltd
# Saved 25348636087: Clicks Recruit (Australia) Pty Ltd
# Saved 81008651723: Codarra Advanced Systems Pty Ltd
# Saved 62125464173: Cogility Consulting Pty Ltd
# Saved 15053788720: Communications Design & Management Pty Ltd
# Saved 90008615745: Compas Pty Ltd
# Saved 69107788401: Cordelta Pty Ltd
# Saved 74120044484: Cosmic Tech Solutions Pty ltd
# Saved 66099766239: CPT Global Australia Pty Ltd
# Saved 31010545267: Data#3 Ltd
# Saved 91102844664: Smarter Contracting Pty Ltd
# Saved 51106981560: SME Gateway Pty Ltd
# Saved 92129869174: SOFTTEST Pays Pty Ltd
# Saved 30090139503: Software AG Australia Pty Ltd
# Saved 71008626131: Southern Cross Computing Pty Ltd
# Saved 99105171819: StarTech IT Consulting Pty Ltd
# Saved 34146766707: Strategic Reform Pty Ltd
# Saved 56146309944: Sunshine Quest Pty Ltd
# Saved 65119369827: Synergy Group Australia Pty Ltd
# Saved 90058352122: SYPAQ Systems Pty Ltd
# Saved 76152219335: Tactiv Pty Ltd
# Saved 95121819305: Talent International (ACT) Pty Ltd
# Saved 28109981777: Tata Consultantcy Services Ltd
# Saved 64141632144: TatvaSoft Australia Pty Ltd
# Saved 41134159434: Tecala ICT Pty Ltd
# Saved 15092511558: Tech Mahindra Limited
# Saved 78083902783: Technology Communications Management Pty Ltd
# Saved 47125859029: Technology, People and Governance Pty Ltd
# Saved 63075561778: Techpoint Consulting Pty Ltd
# Saved 35094755807: Tescom Australasia Pty Ltd
# Saved 76126972030: TestLogistics Pty Ltd
# Saved 48095369403: The Frame Group Pty Ltd
# Saved 13155397541: The Recruitment Hive Pty Ltd
# Saved 65718669825: Thinkstream Pty Ltd
# Saved 34086897636: Titan Recruitment Pty Ltd trading as Titan ICT Consultants
# Saved 72127820071: TRA Global Pty Ltd
# Saved 73008444700: Tracey Brunstrom & Hammond Pty Ltd
# Saved 31105642902: Unisys Australia Pty Ltd
# Saved 83121920938: UXC Consulting Pty Ltd
# Saved 88154144386: Veerpoint Pty Ltd
# Saved 62081001194: Verizon
# Saved 67168829641: VTS Canberra Pty Ltd
# Saved 19125833356: WDScott Asia Pty Ltd
# Saved 12068092491: Westbourne Consulting Pty Ltd
# Saved 52119884945: Whizdom Pty Ltd
# Saved 18093961936: Wipro Ltd

# %%
query = client.query(kind=collection)
query.order = ['Name']

results = list(query.fetch(limit=5))

suppliers_json = []
s1 = datastore.Entity(results[0])
s2 = results[1]

supplier = {}
supplier['ABN'] = s1.key.key.name
supplier['Name'] = s1.key.get('Name')
supplier['State'] = s1.key.get('State')
supplier['Postcode'] = s1.key.get('Postcode')

# %%
suppliers = ''
for r in results:
    s = datastore.Entity(r)
    supplier = {}
    supplier['ABN'] = s.key.key.name
    supplier['Name'] = s.key.get('Name')
    supplier['State'] = s.key.get('State')
    supplier['Postcode'] = s.key.get('Postcode')
    suppliers += json.dumps(supplier) + '\n'
# Out:
# {"ABN": "51 137 899 346", "State": "ACT", "Name": "4DATA Hall 1 Pty Ltd (trading as 4DATA)", "Postcode": 2609}
# {"ABN": "95 127 484 904", "State": "NSW", "Name": "A&A Testing Consultants Pty Ltd", "Postcode": 2620}
# {"ABN": "49 800 667 911", "State": "ACT", "Name": "ACSPRO Pty Ltd", "Postcode": 2600}
# {"ABN": "34 129 384 032", "State": "ACT", "Name": "AGIS Group Pty Ltd", "Postcode": 2602}
# {"ABN": "57 070 045 117", "State": "ACT", "Name": "ASG Group Ltd", "Postcode": 2600}
