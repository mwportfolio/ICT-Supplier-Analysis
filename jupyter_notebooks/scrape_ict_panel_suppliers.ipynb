# %% [markdown]
# This notebook demonstrates using urllib to scrape public supplier and contract information and format/save the output using Pandas and JSONLines.

# %%
import pandas as pd
import urllib.request
import jsonlines

# %% [markdown]
# Scrape list of suppliers and save HTML to local file

# %%
ict_panel_url = 'https://www.tenders.gov.au/?event=public.SON.view&SONUUID=7A6BD483-91A0-5927-C7044D04D7E413EB'

f = urllib.request.urlretrieve(ict_panel_url, "ict_panel_suppliers.html")

# %% [markdown]
# Read HTML from locally stored file into DataFrame

# %%
t = pd.read_html("ict_panel_suppliers.html", attrs={'class': 'genT'}, header=0)
suppliers_df = t[0]
suppliers_df.index = suppliers_df.ABN

print('Suppliers: ' + str(suppliers_df.shape[0]))
# Out:
# Suppliers: 204

# %%
suppliers_df.head()
# Out:
#                                              Supplier Name             ABN  \
# ABN
# 51 137 899 346     4DATA Hall 1 Pty Ltd (trading as 4DATA)  51 137 899 346
# 95 127 484 904             A&A Testing Consultants Pty Ltd  95 127 484 904
# 13 069 942 552  Access Testing Pty Ltd trading as AccessHQ  13 069 942 552
# 52 150 446 521                     AccessibilityOz Pty Ltd  52 150 446 521
# 18 120 507 137                           Accessity Pty Ltd  18 120 507 137
#
#                State  Postcode
# ABN
# 51 137 899 346   ACT      2609
# 95 127 484 904   NSW      2620
# 13 069 942 552   ACT      2602
# 52 150 446 521   VIC      3000
# 18 120 507 137   ACT      2617

# %% [markdown]
# Dump to JSONLines format

# %%
f = open("ict_panel_suppliers.jsonl", "w")
f.write(suppliers_df.to_json(orient='records').replace('},{', '}\n{').replace('[','').replace(']',''))
f.close()

# %% [markdown]
# Confirm the file can be read

# %%
f2 = jsonlines.open("ict_panel_suppliers.jsonl", "r")
for r in f2.iter():
    print(r)
f2.close()
# Out:
# {'Postcode': 2609, 'Supplier Name': '4DATA Hall 1 Pty Ltd (trading as 4DATA)', 'State': 'ACT', 'ABN': '51 137 899 346'}
# {'Postcode': 2620, 'Supplier Name': 'A&A Testing Consultants Pty Ltd', 'State': 'NSW', 'ABN': '95 127 484 904'}
# {'Postcode': 2602, 'Supplier Name': 'Access Testing Pty Ltd trading as AccessHQ', 'State': 'ACT', 'ABN': '13 069 942 552'}
# {'Postcode': 3000, 'Supplier Name': 'AccessibilityOz Pty Ltd', 'State': 'VIC', 'ABN': '52 150 446 521'}
# {'Postcode': 2617, 'Supplier Name': 'Accessity Pty Ltd', 'State': 'ACT', 'ABN': '18 120 507 137'}
# {'Postcode': 2600, 'Supplier Name': 'ACSPRO Pty Ltd', 'State': 'ACT', 'ABN': '49 800 667 911'}
# {'Postcode': 3004, 'Supplier Name': 'Adaps IT Pty Ltd', 'State': 'VIC', 'ABN': '50 169 520 478'}
# {'Postcode': 2612, 'Supplier Name': 'Adelphi Digital Consulting Group Pty Ltd', 'State': 'ACT', 'ABN': '43 096 505 805'}
# {'Postcode': 2602, 'Supplier Name': 'AGIS Group Pty Ltd', 'State': 'ACT', 'ABN': '34 129 384 032'}
# {'Postcode': 2600, 'Supplier Name': 'Ajilon', 'State': 'ACT', 'ABN': '14 007 145 637'}
# {'Postcode': 2612, 'Supplier Name': 'Analytics Group Pty Ltd', 'State': 'ACT', 'ABN': '45 119 601 759'}
# {'Postcode': 2600, 'Supplier Name': 'Apis Group Pty Ltd', 'State': 'ACT', 'ABN': '91 125 472 899'}
# {'Postcode': 2603, 'Supplier Name': 'Aquasora Pty Ltd', 'State': 'ACT', 'ABN': '57 122 300 636'}
# {'Postcode': 2912, 'Supplier Name': 'Aristech Pty Ltd', 'State': 'ACT', 'ABN': '15 126 132 590'}
# {'Postcode': 2065, 'Supplier Name': 'Artis Group Pty Ltd', 'State': 'NSW', 'ABN': '21 116 237 284'}
# {'Postcode': 2600, 'Supplier Name': 'ASG Group Ltd', 'State': 'ACT', 'ABN': '57 070 045 117'}
# {'Postcode': 2600, 'Supplier Name': 'ASPL Australia Pty Ltd', 'State': 'ACT', 'ABN': '83 123 668 940'}
# {'Postcode': 2000, 'Supplier Name': 'Aurec Pty ltd', 'State': 'NSW', 'ABN': '60 103 121 464'}
# {'Postcode': 2612, 'Supplier Name': 'Aviko Pty Ltd', 'State': 'ACT', 'ABN': '90 008 591 008'}
# {'Postcode': 2603, 'Supplier Name': 'BAE Systems Applied Intelligence Pty Limited', 'State': 'ACT', 'ABN': '14 111 187 270'}
# {'Postcode': 2601, 'Supplier Name': 'Balance Recruitment Pty Ltd', 'State': 'ACT', 'ABN': '50 175 029 245'}
# {'Postcode': 4001, 'Supplier Name': 'Beyond Technology International Pty Ltd t/a Beyond Technology', 'State': 'QLD', 'ABN': '76 600 455 963'}
# {'Postcode': 3000, 'Supplier Name': 'BI Group Australia Pty Ltd', 'State': 'VIC', 'ABN': '30 122 228 004'}
# {'Postcode': 3004, 'Supplier Name': 'Biztech Enterprise Solutions', 'State': 'VIC', 'ABN': '26 300 662 281'}
# {'Postcode': 2000, 'Supplier Name': 'Bluefin Resources Pty Ltd', 'State': 'NSW', 'ABN': '48 106 436 837'}
# {'Postcode': 2612, 'Supplier Name': 'Bridge IT Engineering Pty Ltd', 'State': 'ACT', 'ABN': '11 087 255 472'}
# {'Postcode': 2608, 'Supplier Name': 'Bright Consulting', 'State': 'ACT', 'ABN': '85 156 575 647'}
# {'Postcode': 2000, 'Supplier Name': 'BSI People Pty Ltd', 'State': 'NSW', 'ABN': '45 096 568 259'}
# {'Postcode': 2065, 'Supplier Name': 'Bullseye (Asia Pascific) Pty Ltd', 'State': 'NSW', 'ABN': '23 090 593 525'}
# {'Postcode': 4066, 'Supplier Name': 'Business Aspect (ACT) Pty Ltd', 'State': 'QLD', 'ABN': '61 121 411 274'}
# {'Postcode': 2615, 'Supplier Name': 'Bytecode Pty Ltd', 'State': 'ACT', 'ABN': '89 081 322 518'}
# {'Postcode': 2601, 'Supplier Name': 'Callida Consulting', 'State': 'ACT', 'ABN': '40 154 007 664'}
# {'Postcode': 2601, 'Supplier Name': 'Canberra Consulting Pty Ltd', 'State': 'ACT', 'ABN': '57 139 224 436'}
# {'Postcode': 2608, 'Supplier Name': 'Capgemini Australia Pty Ltd', 'State': 'ACT', 'ABN': '11 092 284 314'}
# {'Postcode': 2612, 'Supplier Name': 'CGI Technologies and Solutions Australia Pty Ltd', 'State': 'ACT', 'ABN': '39 001 260 699'}
# {'Postcode': 3000, 'Supplier Name': 'Chamonix IT Management Consulting Pty Ltd', 'State': 'VIC', 'ABN': '27 145 006 006'}
# {'Postcode': 2000, 'Supplier Name': 'Chandler Macleod Group', 'State': 'NSW', 'ABN': '33 090 555 052'}
# {'Postcode': 2601, 'Supplier Name': 'Citadel Systems Pty Ltd', 'State': 'ACT', 'ABN': '45 108 262 942'}
# {'Postcode': 4000, 'Supplier Name': 'Clarity Business and IT Solutions Pty Ltd', 'State': 'QLD', 'ABN': '83 140 112 205'}
# {'Postcode': 2604, 'Supplier Name': 'Clarius Group Ltd', 'State': 'ACT', 'ABN': '43 002 724 334'}
# {'Postcode': 2601, 'Supplier Name': 'Clicks Recruit (Australia) Pty Ltd', 'State': 'ACT', 'ABN': '25 348 636 087'}
# {'Postcode': 2620, 'Supplier Name': 'Codarra Advanced Systems Pty Ltd', 'State': 'ACT', 'ABN': '81 008 651 723'}
# {'Postcode': 4001, 'Supplier Name': 'Cogility Consulting Pty Ltd', 'State': 'QLD', 'ABN': '62 125 464 173'}
# {'Postcode': 2609, 'Supplier Name': 'Communications Design & Management Pty Ltd', 'State': 'ACT', 'ABN': '15 053 788 720'}
# {'Postcode': 2617, 'Supplier Name': 'Compas Pty Ltd', 'State': 'ACT', 'ABN': '90 008 615 745'}
# {'Postcode': 2606, 'Supplier Name': 'Cordelta Pty Ltd', 'State': 'ACT', 'ABN': '69 107 788 401'}
# {'Postcode': 2914, 'Supplier Name': 'Cosmic Tech Solutions Pty ltd', 'State': 'ACT', 'ABN': '74 120 044 484'}
# {'Postcode': 3006, 'Supplier Name': 'CPT Global Australia Pty Ltd', 'State': 'VIC', 'ABN': '66 099 766 239'}
# {'Postcode': 2060, 'Supplier Name': 'Data#3 Ltd', 'State': 'NSW', 'ABN': '31 010 545 267'}
# {'Postcode': 2612, 'Supplier Name': 'Datacom Systems (ACT) Pty Ltd', 'State': 'ACT', 'ABN': '39 135 427 075'}
# {'Postcode': 2604, 'Supplier Name': 'Dataflex Pty Ltd', 'State': 'ACT', 'ABN': '95 008 623 489'}
# {'Postcode': 3000, 'Supplier Name': 'Datatech Consulting Pty Ltd', 'State': 'VIC', 'ABN': '55 124 436 246'}
# {'Postcode': 2086, 'Supplier Name': 'Dell Australia Pty Ltd', 'State': 'NSW', 'ABN': '46 003 855 561'}
# {'Postcode': 2600, 'Supplier Name': 'Delv Pty Ltd', 'State': 'ACT', 'ABN': '30 095 668 223'}
# {'Postcode': 2612, 'Supplier Name': 'Design Managers Australia Pty Ltd', 'State': 'ACT', 'ABN': '33 161 327 171'}
# {'Postcode': 2906, 'Supplier Name': 'Devsgroup Pty Ltd', 'State': 'ACT', 'ABN': '43 121 043 016'}
# {'Postcode': 3000, 'Supplier Name': 'DFP Recruitment Services as Trustee for DFP Business Trust', 'State': 'VIC', 'ABN': '66 394 749 447'}
# {'Postcode': 2602, 'Supplier Name': 'Dialog Pty Ltd', 'State': 'ACT', 'ABN': '16 010 089 175'}
# {'Postcode': 2609, 'Supplier Name': 'Dimension Data Australia Pty Ltd', 'State': 'ACT', 'ABN': '65 003 371 239'}
# {'Postcode': 2059, 'Supplier Name': 'Directory Concepts Pty Ltd', 'State': 'NSW', 'ABN': '30 129 608 448'}
# {'Postcode': 2600, 'Supplier Name': 'DWS (NSW) Pty Ltd', 'State': 'ACT', 'ABN': '93 115 070 301'}
# {'Postcode': 3205, 'Supplier Name': 'Dynamo Recruitment Pty Ltd', 'State': 'VIC', 'ABN': '72 865 179 249'}
# {'Postcode': 2914, 'Supplier Name': 'E-Serve Pty Ltd', 'State': 'ACT', 'ABN': '29 125 037 149'}
# {'Postcode': 2616, 'Supplier Name': 'eConnect Solutions Pty Ltd', 'State': 'ACT', 'ABN': '34 115 058 350'}
# {'Postcode': 4001, 'Supplier Name': 'Eden Ritchie Recruitment Pty Ltd', 'State': 'QLD', 'ABN': '42 072 957 923'}
# {'Postcode': 2611, 'Supplier Name': 'eKonsulting Pty Ltd', 'State': 'ACT', 'ABN': '15 086 357 637'}
# {'Postcode': 4000, 'Supplier Name': 'Emantra Pty Ltd (QLD)', 'State': 'QLD', 'ABN': '98 116 306 453'}
# {'Postcode': 2904, 'Supplier Name': 'Encore IT Services Pty Ltd', 'State': 'ACT', 'ABN': '29 099 576 922'}
# {'Postcode': 2060, 'Supplier Name': 'EPI-USE Australia Pty Ltd', 'State': 'NSW', 'ABN': '74 126 123 108'}
# {'Postcode': 2603, 'Supplier Name': 'Excelerated Consulting Pty ltd', 'State': 'ACT', 'ABN': '30 082 667 776'}
# {'Postcode': 4000, 'Supplier Name': 'Exclaim IT Pty Ltd', 'State': 'QLD', 'ABN': '97 109 189 059'}
# {'Postcode': 2600, 'Supplier Name': 'face2face Recruitment Pty Ltd', 'State': 'ACT', 'ABN': '47 112 122 504'}
# {'Postcode': 4064, 'Supplier Name': 'Facet Consulting Pty Ltd', 'State': 'QLD', 'ABN': '93 103 238 759'}
# {'Postcode': 2000, 'Supplier Name': 'Finite Group APAC Pty Ltd', 'State': 'NSW', 'ABN': '43 085 406 300'}
# {'Postcode': 2617, 'Supplier Name': 'Finkisoft Pty Ltd', 'State': 'ACT', 'ABN': '98 127 371 064'}
# {'Postcode': 2615, 'Supplier Name': 'Foresight IT Consulting Pty Ltd', 'State': 'ACT', 'ABN': '82 119 675 204'}
# {'Postcode': 2612, 'Supplier Name': 'Frontier Group Australia Pty Ltd', 'State': 'ACT', 'ABN': '77 087 743 879'}
# {'Postcode': 2609, 'Supplier Name': 'Fuji Xerox Australia Pty Ltd', 'State': 'ACT', 'ABN': '63 000 341 819'}
# {'Postcode': 2612, 'Supplier Name': 'Fujitsu Australia Ltd', 'State': 'ACT', 'ABN': '19 001 011 427'}
# {'Postcode': 2602, 'Supplier Name': 'Funnelback Pty Ltd', 'State': 'ACT', 'ABN': '34 116 105 296'}
# {'Postcode': 2600, 'Supplier Name': 'Gel Gov Group Pty Ltd', 'State': 'ACT', 'ABN': '46 008 617 114'}
# {'Postcode': 4305, 'Supplier Name': 'Global Skill Exchange Pty Ltd', 'State': 'QLD', 'ABN': '35 129 590 656'}
# {'Postcode': 2607, 'Supplier Name': 'GMT Canberra Pty Ltd', 'State': 'ACT', 'ABN': '81 103 672 439'}
# {'Postcode': 2000, 'Supplier Name': 'Gordon Group Consulting Pty Ltd', 'State': 'NSW', 'ABN': '86 104 362 576'}
# {'Postcode': 3001, 'Supplier Name': 'Grant Thornton Australia Pty Ltd', 'State': 'VIC', 'ABN': '41 127 556 389'}
# {'Postcode': 2620, 'Supplier Name': 'GrayMorr Consulting Pty Ltd', 'State': 'NSW', 'ABN': '87 129 502 567'}
# {'Postcode': 2601, 'Supplier Name': 'Greythorn Pty Ltd', 'State': 'ACT', 'ABN': '57 071 352 031'}
# {'Postcode': 2601, 'Supplier Name': 'Hamilton James & Bruce Pty Ltd', 'State': 'ACT', 'ABN': '11 002 921 468'}
# {'Postcode': 2601, 'Supplier Name': 'Hays Specialist Recruitment (Australia) Pty Ltd', 'State': 'ACT', 'ABN': '47 001 407 281'}
# {'Postcode': 2000, 'Supplier Name': 'HiTech Group Australia Ltd', 'State': 'NSW', 'ABN': '41 062 067 878'}
# {'Postcode': 2060, 'Supplier Name': 'Holocentric Pty Ltd', 'State': 'NSW', 'ABN': '73 052 972 095'}
# {'Postcode': 2000, 'Supplier Name': 'Horizon Consulting Pty Ltd', 'State': 'NSW', 'ABN': '67 100 724 338'}
# {'Postcode': 2600, 'Supplier Name': 'Hudson Global Resources (Aust) Pty Ltd', 'State': 'ACT', 'ABN': '21 002 888 762'}
# {'Postcode': 2600, 'Supplier Name': 'IBM Australia Ltd', 'State': 'ACT', 'ABN': '79 000 024 733'}
# {'Postcode': 2107, 'Supplier Name': 'ICM Consulting Pty Ltd', 'State': 'NSW', 'ABN': '64 143 127 404'}
# {'Postcode': 2601, 'Supplier Name': 'iCognition Pty Ltd', 'State': 'ACT', 'ABN': '92 104 128 001'}
# {'Postcode': 2060, 'Supplier Name': 'IMA Management and Technology Pty Ltd', 'State': 'NSW', 'ABN': '78 159 837 939'}
# {'Postcode': 2000, 'Supplier Name': 'Implementation Soft Australia Pty Ltd', 'State': 'NSW', 'ABN': '52 112 055 302'}
# {'Postcode': 2612, 'Supplier Name': 'Infinite Consulting Pty Ltd', 'State': 'ACT', 'ABN': '56 081 954 645'}
# {'Postcode': 2605, 'Supplier Name': 'InfoFocus', 'State': 'ACT', 'ABN': '44 001 835 838'}
# {'Postcode': 2603, 'Supplier Name': 'InfoRail Pty Ltd', 'State': 'ACT', 'ABN': '33 008 615 441'}
# {'Postcode': 3000, 'Supplier Name': 'Information Management Careers Pty Ltd', 'State': 'VIC', 'ABN': '57 146 661 494'}
# {'Postcode': 3008, 'Supplier Name': 'Infosys Technologies Limited', 'State': 'VIC', 'ABN': '52 090 591 209'}
# {'Postcode': 2905, 'Supplier Name': 'Innovative Business Computing Pty Ltd', 'State': 'ACT', 'ABN': '40 073 110 022'}
# {'Postcode': 2914, 'Supplier Name': 'Inspired Apps Pty Ltd', 'State': 'ACT', 'ABN': '71 145 171 071'}
# {'Postcode': 2022, 'Supplier Name': 'Intech Solutions Pty Ltd', 'State': 'NSW', 'ABN': '45 002 812 697'}
# {'Postcode': 2500, 'Supplier Name': 'Internet Solutions Australia Pty Ltd', 'State': 'NSW', 'ABN': '65 108 451 378'}
# {'Postcode': 2000, 'Supplier Name': 'Interpro Australia Pty Ltd', 'State': 'NSW', 'ABN': '59 086 726 374'}
# {'Postcode': 2615, 'Supplier Name': 'Ionize Pty Ltd', 'State': 'ACT', 'ABN': '62 132 569 941'}
# {'Postcode': 2060, 'Supplier Name': 'IT Newcom Pty Ltd', 'State': 'NSW', 'ABN': '50 077 613 828'}
# {'Postcode': 3000, 'Supplier Name': 'Itcom Australia Pty Ltd', 'State': 'VIC', 'ABN': '67 064 911 404'}
# {'Postcode': 2600, 'Supplier Name': 'Jacobs Australia Pty Limited', 'State': 'ACT', 'ABN': '12 079 749 287'}
# {'Postcode': 4226, 'Supplier Name': 'K.J.Ross & Associates Pty Ltd', 'State': 'QLD', 'ABN': '11 079 218 652'}
# {'Postcode': 7000, 'Supplier Name': 'Knight Errant Pty Ltd', 'State': 'TAS', 'ABN': '68 091 099 151'}
# {'Postcode': 2606, 'Supplier Name': 'Kohlbahdin Pty Ltd', 'State': 'ACT', 'ABN': '77 067 178 778'}
# {'Postcode': 2604, 'Supplier Name': 'Konica Minolta Business Solutions Australia Pty Ltd', 'State': 'ACT', 'ABN': '50 001 065 096'}
# {'Postcode': 2609, 'Supplier Name': 'KPMG', 'State': 'ACT', 'ABN': '51 194 660 183'}
# {'Postcode': 3000, 'Supplier Name': 'Ladoo Pty Ltd', 'State': 'VIC', 'ABN': '71 147 121 551'}
# {'Postcode': 2000, 'Supplier Name': 'Leo Microsystems Pty Ltd', 'State': 'NSW', 'ABN': '43 120 297 092'}
# {'Postcode': 2609, 'Supplier Name': 'M&T Resources Pty Ltd', 'State': 'ACT', 'ABN': '27 132 349 458'}
# {'Postcode': 3121, 'Supplier Name': 'Macro Recruitment Australasia Pty Ltd', 'State': 'VIC', 'ABN': '25 103 297 552'}
# {'Postcode': 2000, 'Supplier Name': 'Manpower Services (Australia) Pty Ltd', 'State': 'NSW', 'ABN': '15 071 884 994'}
# {'Postcode': 2077, 'Supplier Name': 'Merewyn Partners Pty Ltd', 'State': 'NSW', 'ABN': '42 152 757 929'}
# {'Postcode': 2060, 'Supplier Name': 'MIP (Aust) Pty Ltd', 'State': 'NSW', 'ABN': '21 111 378 968'}
# {'Postcode': 2904, 'Supplier Name': 'MXA Consulting Pty Ltd', 'State': 'ACT', 'ABN': '16 233 295 918'}
# {'Postcode': 2759, 'Supplier Name': 'National Technical Services Pty Ltd', 'State': 'NSW', 'ABN': '96 059 802 934'}
# {'Postcode': 2067, 'Supplier Name': 'NCSI Australia Pty Ltd', 'State': 'NSW', 'ABN': '38 089 983 317'}
# {'Postcode': 3170, 'Supplier Name': 'NEC Australia Pty Ltd', 'State': 'VIC', 'ABN': '86 001 217 527'}
# {'Postcode': 2000, 'Supplier Name': 'NetReturn Consulting Pty Ltd', 'State': 'NSW', 'ABN': '71 124 587 426'}
# {'Postcode': 2612, 'Supplier Name': 'Northrop Grumman M5 Network Security Pty Ltd', 'State': 'ACT', 'ABN': '58 101 674 444'}
# {'Postcode': 3000, 'Supplier Name': 'Nous Group Pty Ltd', 'State': 'VIC', 'ABN': '66 086 210 344'}
# {'Postcode': 2612, 'Supplier Name': 'NTT Com ICT Solutions Australia Pty Ltd', 'State': 'ACT', 'ABN': '61 059 040 998'}
# {'Postcode': 4008, 'Supplier Name': 'NTT DATA Business Solutions Australia Pty Ltd', 'State': 'QLD', 'ABN': '78 106 676 359'}
# {'Postcode': 2604, 'Supplier Name': 'Oakton Contracting and Recruitment Pty Ltd', 'State': 'ACT', 'ABN': '80 077 571 843'}
# {'Postcode': 2904, 'Supplier Name': 'Omaha IT Services Pty Ltd', 'State': 'ACT', 'ABN': '50 050 494 196'}
# {'Postcode': 2913, 'Supplier Name': 'Online 89 Pty Ltd', 'State': 'ACT', 'ABN': '36 008 658 017'}
# {'Postcode': 2606, 'Supplier Name': 'OPC IT Pty Ltd', 'State': 'ACT', 'ABN': '29 008 657 618'}
# {'Postcode': 2601, 'Supplier Name': 'Optus Network Pty Ltd', 'State': 'ACT', 'ABN': '92 008 570 330'}
# {'Postcode': 2612, 'Supplier Name': 'Paxus Australia Pty Ltd', 'State': 'ACT', 'ABN': '35 004 609 616'}
# {'Postcode': 2000, 'Supplier Name': 'Pegasus Global Pty Ltd', 'State': 'NSW', 'ABN': '72 106 208 066'}
# {'Postcode': 2606, 'Supplier Name': 'Peoplebank Australia Ltd', 'State': 'NSW', 'ABN': '42 003 995 748'}
# {'Postcode': 2617, 'Supplier Name': 'Perocin Pty Ltd', 'State': 'ACT', 'ABN': '15 079 494 518'}
# {'Postcode': 2620, 'Supplier Name': 'Phoenix Management Services Pty Ltd', 'State': 'NSW', 'ABN': '11 151 887 802'}
# {'Postcode': 2609, 'Supplier Name': 'PLAUT IT (Australia) Pty Ltd', 'State': 'ACT', 'ABN': '17 092 547 218'}
# {'Postcode': 3146, 'Supplier Name': 'Powerdata Group Consulting Pty Ltd', 'State': 'VIC', 'ABN': '15 107 160 770'}
# {'Postcode': 1765, 'Supplier Name': 'Precision Consulting Corporation Pty Limited', 'State': 'NSW', 'ABN': '91 131 039 506'}
# {'Postcode': 2601, 'Supplier Name': 'Predicate Partners Pty Ltd', 'State': 'ACT', 'ABN': '34 128 711 348'}
# {'Postcode': 2905, 'Supplier Name': 'Procurement Professionals Pty Ltd', 'State': 'ACT', 'ABN': '20 076 432 212'}
# {'Postcode': 2000, 'Supplier Name': 'Programmed Professionals Pty Ltd', 'State': 'NSW', 'ABN': '40 124 764 245'}
# {'Postcode': 2000, 'Supplier Name': 'Project People Consulting Pty Ltd', 'State': 'NSW', 'ABN': '69 109 750 647'}
# {'Postcode': 2600, 'Supplier Name': 'Providence Consulting Group Pty Ltd as Trustee for Providence Consulting Group Unit Trust', 'State': 'ACT', 'ABN': 'Exempt'}
# {'Postcode': 2604, 'Supplier Name': 'Proximity Advisory Services Pty Ltd', 'State': 'ACT', 'ABN': '92 147 937 844'}
# {'Postcode': 2603, 'Supplier Name': 'PwC Australia', 'State': 'ACT', 'ABN': '52 780 433 757'}
# {'Postcode': 2911, 'Supplier Name': 'Qirx Pty Ltd', 'State': 'ACT', 'ABN': '62 092 934 659'}
# {'Postcode': 2137, 'Supplier Name': 'QR Solutions Pty Ltd', 'State': 'NSW', 'ABN': '42 110 324 788'}
# {'Postcode': 2537, 'Supplier Name': 'Rapid Technology Group Pty Ltd', 'State': 'NSW', 'ABN': '15 098 987 190'}
# {'Postcode': 2600, 'Supplier Name': 'Redback Consulting Pty Ltd', 'State': 'ACT', 'ABN': '50 104 427 161'}
# {'Postcode': 2000, 'Supplier Name': 'Revolution IT Pty Ltd', 'State': 'ACT', 'ABN': '32 107 913 342'}
# {'Postcode': 2603, 'Supplier Name': 'Ridgeline Solutions Australia Pty Ltd', 'State': 'ACT', 'ABN': '43 125 552 383'}
# {'Postcode': 2040, 'Supplier Name': 'RNC Pty Ltd', 'State': 'NSW', 'ABN': '18 086 411 467'}
# {'Postcode': 2615, 'Supplier Name': 'Roll Inn Pty Ltd', 'State': 'ACT', 'ABN': '73 153 698 036'}
# {'Postcode': 2602, 'Supplier Name': 'RPV Consultants Pty Ltd', 'State': 'ACT', 'ABN': '97 117 432 354'}
# {'Postcode': 3000, 'Supplier Name': 'RXP Services Ltd', 'State': 'VIC', 'ABN': '30 146 959 917'}
# {'Postcode': 2600, 'Supplier Name': 'Saltbush Consulting Pty Ltd', 'State': 'ACT', 'ABN': '58 134 662 963'}
# {'Postcode': 2066, 'Supplier Name': 'SAS Institute Australia Pty Ltd', 'State': 'NSW', 'ABN': '13 002 287 247'}
# {'Postcode': 2601, 'Supplier Name': 'Sensory7 Pty Ltd', 'State': 'ACT', 'ABN': '75 089 625 436'}
# {'Postcode': 2904, 'Supplier Name': 'Sentio Consulting Pty Ltd', 'State': 'ACT', 'ABN': '89 151 227 511'}
# {'Postcode': 2057, 'Supplier Name': 'Shearwater Solutions Pty Ltd', 'State': 'NSW', 'ABN': '96 083 648 524'}
# {'Postcode': 2606, 'Supplier Name': 'Smarter Contracting Pty Ltd', 'State': 'ACT', 'ABN': '91 102 844 664'}
# {'Postcode': 2604, 'Supplier Name': 'SME Gateway Pty Ltd', 'State': 'ACT', 'ABN': '51 106 981 560'}
# {'Postcode': 2913, 'Supplier Name': 'SOFTTEST Pays Pty Ltd', 'State': 'ACT', 'ABN': '92 129 869 174'}
# {'Postcode': 2060, 'Supplier Name': 'Software AG Australia Pty Ltd', 'State': 'NSW', 'ABN': '30 090 139 503'}
# {'Postcode': 2600, 'Supplier Name': 'Southern Cross Computing Pty Ltd', 'State': 'ACT', 'ABN': '71 008 626 131'}
# {'Postcode': 2607, 'Supplier Name': 'StarTech IT Consulting Pty Ltd', 'State': 'ACT', 'ABN': '99 105 171 819'}
# {'Postcode': 2913, 'Supplier Name': 'Strategic Reform Pty Ltd', 'State': 'ACT', 'ABN': '34 146 766 707'}
# {'Postcode': 2615, 'Supplier Name': 'Sunshine Quest Pty Ltd', 'State': 'ACT', 'ABN': '56 146 309 944'}
# {'Postcode': 2600, 'Supplier Name': 'Synergy Group Australia Pty Ltd', 'State': 'ACT', 'ABN': '65 119 369 827'}
# {'Postcode': 3004, 'Supplier Name': 'SYPAQ Systems Pty Ltd', 'State': 'VIC', 'ABN': '90 058 352 122'}
# {'Postcode': 4101, 'Supplier Name': 'Tactiv Pty Ltd', 'State': 'QLD', 'ABN': '76 152 219 335'}
# {'Postcode': 2600, 'Supplier Name': 'Talent International (ACT) Pty Ltd', 'State': 'ACT', 'ABN': '95 121 819 305'}
# {'Postcode': 2060, 'Supplier Name': 'Tata Consultantcy Services Ltd', 'State': 'NSW', 'ABN': '28 109 981 777'}
# {'Postcode': 2072, 'Supplier Name': 'TatvaSoft Australia Pty Ltd', 'State': 'NSW', 'ABN': '64 141 632 144'}
# {'Postcode': 2153, 'Supplier Name': 'Tecala ICT Pty Ltd', 'State': 'NSW', 'ABN': '41 134 159 434'}
# {'Postcode': 2601, 'Supplier Name': 'Tech Mahindra Limited', 'State': 'ACT', 'ABN': '15 092 511 558'}
# {'Postcode': 2614, 'Supplier Name': 'Technology Communications Management Pty Ltd', 'State': 'ACT', 'ABN': '78 083 902 783'}
# {'Postcode': 2902, 'Supplier Name': 'Technology, People and Governance Pty Ltd', 'State': 'ACT', 'ABN': '47 125 859 029'}
# {'Postcode': 2258, 'Supplier Name': 'Techpoint Consulting Pty Ltd', 'State': 'NSW', 'ABN': '63 075 561 778'}
# {'Postcode': 2602, 'Supplier Name': 'Tescom Australasia Pty Ltd', 'State': 'ACT', 'ABN': '35 094 755 807'}
# {'Postcode': 2000, 'Supplier Name': 'TestLogistics Pty Ltd', 'State': 'NSW', 'ABN': '76 126 972 030'}
# {'Postcode': 2001, 'Supplier Name': 'The Frame Group Pty Ltd', 'State': 'NSW', 'ABN': '48 095 369 403'}
# {'Postcode': 2620, 'Supplier Name': 'The Recruitment Hive Pty Ltd', 'State': 'ACT', 'ABN': '13 155 397 541'}
# {'Postcode': 2609, 'Supplier Name': 'Thinkstream Pty Ltd', 'State': 'ACT', 'ABN': '65 718 669 825'}
# {'Postcode': 6005, 'Supplier Name': 'Titan Recruitment Pty Ltd trading as Titan ICT Consultants', 'State': 'WA', 'ABN': '34 086 897 636'}
# {'Postcode': 2000, 'Supplier Name': 'TRA Global Pty Ltd', 'State': 'NSW', 'ABN': '72 127 820 071'}
# {'Postcode': 2060, 'Supplier Name': 'Tracey Brunstrom & Hammond Pty Ltd', 'State': 'NSW', 'ABN': '73 008 444 700'}
# {'Postcode': 2600, 'Supplier Name': 'Unisys Australia Pty Ltd', 'State': 'ACT', 'ABN': '31 105 642 902'}
# {'Postcode': 2609, 'Supplier Name': 'UXC Consulting Pty Ltd', 'State': 'ACT', 'ABN': '83 121 920 938'}
# {'Postcode': 2905, 'Supplier Name': 'Veerpoint Pty Ltd', 'State': 'ACT', 'ABN': '88 154 144 386'}
# {'Postcode': 2602, 'Supplier Name': 'Verizon', 'State': 'ACT', 'ABN': '62 081 001 194'}
# {'Postcode': 2085, 'Supplier Name': 'VTS Canberra Pty Ltd', 'State': 'NSW', 'ABN': '67 168 829 641'}
# {'Postcode': 2600, 'Supplier Name': 'WDScott Asia Pty Ltd', 'State': 'ACT', 'ABN': '19 125 833 356'}
# {'Postcode': 2605, 'Supplier Name': 'Westbourne Consulting Pty Ltd', 'State': 'ACT', 'ABN': '12 068 092 491'}
# {'Postcode': 2617, 'Supplier Name': 'Whizdom Pty Ltd', 'State': 'ACT', 'ABN': '52 119 884 945'}
# {'Postcode': 2600, 'Supplier Name': 'Wipro Ltd', 'State': 'ACT', 'ABN': '18 093 961 936'}
